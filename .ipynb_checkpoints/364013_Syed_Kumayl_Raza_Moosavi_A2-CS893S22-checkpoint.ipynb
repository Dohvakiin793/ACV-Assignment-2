# %% [markdown]
# #Assignment 2
# #Author: Syed Kumayl Raza Moosavi - 364013
#
# #The x and y coordination and the annotations are stored in .npy files.
# #Use Python numpy to read the files separated with a semi-colon.
#
# #Expression: expression ID of the face
# #(0: Neutral, 1: Happy, 2: Sad, 3: Surprise, 4:Fear, 5: Disgust, 6: Anger, 7: Contempt)
#
# #Valence: valence value of the expression in interval [-1,+1] (for Uncertain and Noface categories the value is -2)
#     #Continuous values from -1 (negative/unpleasant) to +1 (positive/pleasant)
#
# #Arousal: arousal value of the expression in interval [-1,+1] (for Uncertain and No-face categories the value is -2)
#     #Continuous values from -1 (Tired) to +1 (Active)
#
# #Task:
# #----> Use appropriate CNN architecture recognition of Facial Expression, and computing Valence and Arousal
# #----> use at least two CNN baselines (VGG, ResNet, Inception, Xception, MobileNet, EfficientNet, SE Net, DenseNet or any other … etc)

# %% [markdown]
# Part 1
#
# Use simple numpy functions to extract a part of the data and test to see the proposed model is working

# %%
#!pip install keras
# !pip install tensorflow
#!pip install numpy
#!pip install opencv-python

import numpy as np
import os
import tensorflow as tf
import skimage.io
import natsort
import cv2

from matplotlib import pyplot as plt
import random
import time

# %%
def load_images(current_directory):
    # lists to store Images and labels
    images = []

    file_names = [os.path.join(current_directory,file) 
                  for file in os.listdir(current_directory)
                  if file.endswith('.jpg')
                 ]
    file_name=natsort.natsorted(file_names);
    #file_names.sort()
    # Load all given Images into the Images array
    for file in file_name:
        images.append(skimage.io.imread(file))
    print('Successfully Loaded {0} images!'.format(len(images)), "Shape:", np.array(images).shape)
    
    return np.array(images)    

def load_annotations(current_directory):
    # lists to store Images and labels
    arousal = []
    valence = []
    landmarks = []
    expression = []
    filesd = []

    file_names = [os.path.join(current_directory,file) 
                  for file in os.listdir(current_directory)
                  if file.endswith('.npy')
                 ]    
    file_name=natsort.natsorted(file_names);
    #file_names.sort()
    # Load all given Images into the Images array
    for file in file_name:
        filesd.append(file)
        if "_lnd" in file:
            landland = np.load(file).reshape(68,2)
            landmarks.append(landland)#np.load(file))
        if "_aro" in file:
            arousal.append(np.load(file))
        if "_exp" in file:
            expression.append(np.load(file))
        if "_val" in file:
            valence.append(np.load(file))
    print('Successfully Loaded {0} Landmarks!'.format(len(landmarks)), "Shape:", np.array(landmarks).shape)
    print('Successfully Loaded {0} Arousal!'.format(len(arousal)), "Shape:", np.array(arousal).shape)
    print('Successfully Loaded {0} Expression!'.format(len(expression)), "Shape:", np.array(expression).shape)
    print('Successfully Loaded {0} Valence!'.format(len(valence)), "Shape:", np.array(valence).shape)
    
    return np.array(landmarks),np.array(arousal),np.array(expression),np.array(valence),np.array(filesd)

def show(img,shape):
    #skimage.io.imshow(img)
    #plt.show()
    # Display the landmarks
    #shape_np = np.zeros((68, 2), dtype="int")
    # Draw the circle to mark the keypoint 
    for i in range(68):
        imga = cv2.circle(img, (round(shape[i][0]),round(shape[i][1])), radius=1, color=(0, 0, 255), thickness=-1)
    # Display the image
    
    cv2.imshow("Image with Facial landmarks",imga)
    cv2.waitKey(0)
    #skimage.io.imshow(img)
    #plt.show()

# %%
#Train images and annotations

images = load_images('test_set/val_set/images2');
[landmarks,arousal,expression,valence,filles] = load_annotations('test_set/val_set/annotations2');
# Out:
# Successfully Loaded 26 images! Shape: (26, 224, 224, 3)
# Successfully Loaded 26 Landmarks! Shape: (26, 68, 2)
# Successfully Loaded 26 Arousal! Shape: (26,)
# Successfully Loaded 26 Expression! Shape: (26,)
# Successfully Loaded 26 Valence! Shape: (26,)

# %%
#Sample show image with landmark features
abc = random.randint(0,images.shape[0]-1)
show(images[abc],landmarks[abc])

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import Lambda
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.utils.vis_utils import plot_model
from keras.layers.merge import concatenate
import tensorflow_addons as tfa
from keras.metrics import AUC
from tensorflow_addons.metrics import MatthewsCorrelationCoefficient as CORR
from tensorflow_addons.metrics import CohenKappa as Cohen_Kappa
from tensorflow_addons.metrics import F1Score as F1_Score

# %%
# Creating a CNN model with many VGG blocks

# function for creating a vgg block
def vgg_block(layer_in, n_filters, n_conv):
	# add convolutional layers
	for _ in range(n_conv):
		layer_in = Conv2D(n_filters, (3,3), padding='same', activation='relu')(layer_in)
	# add max pooling layer
	layer_in = MaxPooling2D((2,2), strides=(2,2))(layer_in)
	return layer_in
 
# define model input
visible = Input(shape=(224, 224, 3))  #image
visible2 = Input(shape=(68, 2))   #expressions


# add vgg module
layer1 = vgg_block(visible, 64, 2)
# add vgg module
layer2 = vgg_block(layer1, 128, 2)
# add vgg module
layer3 = vgg_block(layer2, 256, 3)
# add vgg module
layer4 = vgg_block(layer3, 512, 3)
# add vgg module
layer5 = vgg_block(layer4, 512, 3)

layer6_1 = Flatten()(layer5)
layer6_2 = Flatten()(visible2)

layer6 = concatenate([layer6_1, layer6_2])
layer7 = Dense(4096, activation='relu')(layer6)
layer8 = Dense(4096, activation='relu')(layer7)


# Output layer for classification (1000 classes)
layer_class = Dense(8, activation='softmax')(layer8)


layer_arousal = Dense(1, activation='linear')(layer8)

layer_val = Dense(1, activation='linear')(layer8)


classification_output = Lambda(lambda x:x, name = "classification_output")(layer_class)
arousal_output = Lambda(lambda x:x, name = "arousal_output")(layer_arousal)
valence_output = Lambda(lambda x:x, name = "valence_output")(layer_val)

# create model
model = Model(inputs=[visible,visible2], outputs=[classification_output,arousal_output,valence_output])


#macro parameters
model.compile(loss=['categorical_crossentropy', 'mse', 'mse'],
              optimizer='adam', metrics={"classification_output":['accuracy',
                                                                  Cohen_Kappa(num_classes=8),
                                                                  F1_Score(num_classes=8),
                                                                  AUC(curve='ROC',name = 'AUC-ROC'), 
                                                                  AUC(curve='PR',name = 'AUC-PR')], 
                                         "arousal_output":['RootMeanSquaredError',
                                                          correlationMetric, 
                                                           CCC], 
                                         "valence_output":['RootMeanSquaredError',
                                                          correlationMetric,
                                                           CCC]}, 
              run_eagerly=True)



# summarize model
model.summary()
# plot model architecture
#plot_model(model, show_shapes=True, to_file='vgg_block.png')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 256)  590080      ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 256)  590080      ['conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0          ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 512)  2359808     ['conv2d_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 512)  2359808     ['conv2d_8[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 14, 14, 512)  2359808     ['max_pooling2d_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 14, 14, 512)  2359808     ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 14, 14, 512)  2359808     ['conv2d_11[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 7, 7, 512)   0           ['conv2d_12[0][0]']
#
#  input_2 (InputLayer)           [(None, 68, 2)]      0           []
#
#  flatten (Flatten)              (None, 25088)        0           ['max_pooling2d_4[0][0]']
#
#  flatten_1 (Flatten)            (None, 136)          0           ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 25224)        0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  dense (Dense)                  (None, 4096)         103321600   ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 4096)         16781312    ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 8)            32776       ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 1)            4097        ['dense_1[0][0]']
#
#  dense_4 (Dense)                (None, 1)            4097        ['dense_1[0][0]']
#
#  classification_output (Lambda)  (None, 8)           0           ['dense_2[0][0]']
#
#  arousal_output (Lambda)        (None, 1)            0           ['dense_3[0][0]']
#
#  valence_output (Lambda)        (None, 1)            0           ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 134,858,570
# Trainable params: 134,858,570
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit([images, landmarks],[expressions,arousals,valences], batch_size=2, epochs=5, validation_split=0.2)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 3s 3s/step - loss: 84.4360 - classification_output_loss: 14.6160 - arousal_output_loss: 1.5323 - valence_output_loss: 68.2878 - classification_output_accuracy: 0.0000e+00 - classification_output_cohen_kappa: 0.0000e+00 - classification_output_f1_score: 0.0000e+00 - classification_output_AUC-ROC: 0.2143 - classification_output_AUC-PR: 0.0767 - arousal_output_root_mean_squared_error: 1.2379 - arousal_output_correlationMetric: nan - arousal_output_CCC: 0.0000e+00 - valence_output_root_mean_squared_error: 8.2636 - valence_output_correlationMetric: nan - valence_output_CCC: 0.0000e+00 - val_loss: 763267840.0000 - val_classification_output_loss: 3949.4102 - val_arousal_output_loss: 11972321.0000 - val_valence_output_loss: 751291584.0000 - val_classification_output_accuracy: 0.0000e+00 - val_classification_output_cohen_kappa: 0.0000e+00 - val_classification_output_f1_score: 0.0000e+00 - val_classification_output_AUC-ROC: 0.4286 - val_classification_output_AUC-PR: 0.1004 - val_arousal_output_root_mean_squared_error: 3460.1042 - val_arousal_output_correlationMetric: nan - val_arousal_output_CCC: 0.0000e+00 - val_valence_output_root_mean_squared_error: 27409.6992 - val_valence_output_correlationMetric: nan - val_valence_output_CCC: 0.0000e+00
# Epoch 2/5
# 1/1 [==============================] - 2s 2s/step - loss: 708725376.0000 - classification_output_loss: 0.0000e+00 - arousal_output_loss: 11101860.0000 - valence_output_loss: 697623488.0000 - classification_output_accuracy: 1.0000 - classification_output_cohen_kappa: nan - classification_output_f1_score: 0.1250 - classification_output_AUC-ROC: 1.0000 - classification_output_AUC-PR: 1.0000 - arousal_output_root_mean_squared_error: 3331.9453 - arousal_output_correlationMetric: nan - arousal_output_CCC: 0.0000e+00 - valence_output_root_mean_squared_error: 26412.5625 - valence_output_correlationMetric: nan - valence_output_CCC: 0.0000e+00 - val_loss: 12313.7949 - val_classification_output_loss: 49.0390 - val_arousal_output_loss: 0.6007 - val_valence_output_loss: 12264.1553 - val_classification_output_accuracy: 0.0000e+00 - val_classification_output_cohen_kappa: 0.0000e+00 - val_classification_output_f1_score: 0.0000e+00 - val_classification_output_AUC-ROC: 0.4286 - val_classification_output_AUC-PR: 0.1004 - val_arousal_output_root_mean_squared_error: 0.7750 - val_arousal_output_correlationMetric: nan - val_arousal_output_CCC: 0.0000e+00 - val_valence_output_root_mean_squared_error: 110.7436 - val_valence_output_correlationMetric: nan - val_valence_output_CCC: 0.0000e+00
# Epoch 3/5
# 1/1 [==============================] - 2s 2s/step - loss: 11588.6318 - classification_output_loss: 0.0000e+00 - arousal_output_loss: 1.7319 - valence_output_loss: 11586.9004 - classification_output_accuracy: 1.0000 - classification_output_cohen_kappa: nan - classification_output_f1_score: 0.1250 - classification_output_AUC-ROC: 1.0000 - classification_output_AUC-PR: 1.0000 - arousal_output_root_mean_squared_error: 1.3160 - arousal_output_correlationMetric: nan - arousal_output_CCC: 0.0000e+00 - valence_output_root_mean_squared_error: 107.6425 - valence_output_correlationMetric: nan - valence_output_CCC: 0.0000e+00 - val_loss: 25934.5645 - val_classification_output_loss: 11.5135 - val_arousal_output_loss: 857.1738 - val_valence_output_loss: 25065.8770 - val_classification_output_accuracy: 0.0000e+00 - val_classification_output_cohen_kappa: 0.0000e+00 - val_classification_output_f1_score: 0.0000e+00 - val_classification_output_AUC-ROC: 0.4286 - val_classification_output_AUC-PR: 0.1004 - val_arousal_output_root_mean_squared_error: 29.2775 - val_arousal_output_correlationMetric: nan - val_arousal_output_CCC: 0.0000e+00 - val_valence_output_root_mean_squared_error: 158.3221 - val_valence_output_correlationMetric: nan - val_valence_output_CCC: 0.0000e+00
# Epoch 4/5
# 1/1 [==============================] - 1s 1s/step - loss: 24037.4043 - classification_output_loss: 0.0032 - arousal_output_loss: 777.9214 - valence_output_loss: 23259.4805 - classification_output_accuracy: 1.0000 - classification_output_cohen_kappa: nan - classification_output_f1_score: 0.1250 - classification_output_AUC-ROC: 1.0000 - classification_output_AUC-PR: 1.0000 - arousal_output_root_mean_squared_error: 27.8912 - arousal_output_correlationMetric: nan - arousal_output_CCC: 0.0000e+00 - valence_output_root_mean_squared_error: 152.5106 - valence_output_correlationMetric: nan - valence_output_CCC: 0.0000e+00 - val_loss: 33638.8359 - val_classification_output_loss: 27.1622 - val_arousal_output_loss: 1151.9243 - val_valence_output_loss: 32459.7500 - val_classification_output_accuracy: 0.0000e+00 - val_classification_output_cohen_kappa: 0.0000e+00 - val_classification_output_f1_score: 0.0000e+00 - val_classification_output_AUC-ROC: 0.4286 - val_classification_output_AUC-PR: 0.1004 - val_arousal_output_root_mean_squared_error: 33.9400 - val_arousal_output_correlationMetric: nan - val_arousal_output_CCC: 0.0000e+00 - val_valence_output_root_mean_squared_error: 180.1659 - val_valence_output_correlationMetric: nan - val_valence_output_CCC: 0.0000e+00
# Epoch 5/5
# 1/1 [==============================] - 1s 1s/step - loss: 30871.3281 - classification_output_loss: 0.0000e+00 - arousal_output_loss: 1005.8815 - valence_output_loss: 29865.4473 - classification_output_accuracy: 1.0000 - classification_output_cohen_kappa: nan - classification_output_f1_score: 0.1250 - classification_output_AUC-ROC: 1.0000 - classification_output_AUC-PR: 1.0000 - arousal_output_root_mean_squared_error: 31.7156 - arousal_output_correlationMetric: nan - arousal_output_CCC: 0.0000e+00 - valence_output_root_mean_squared_error: 172.8162 - valence_output_correlationMetric: nan - valence_output_CCC: 0.0000e+00 - val_loss: 31952.8184 - val_classification_output_loss: 53.0105 - val_arousal_output_loss: 1709.8612 - val_valence_output_loss: 30189.9473 - val_classification_output_accuracy: 0.0000e+00 - val_classification_output_cohen_kappa: 0.0000e+00 - val_classification_output_f1_score: 0.0000e+00 - val_classification_output_AUC-ROC: 0.4286 - val_classification_output_AUC-PR: 0.1004 - val_arousal_output_root_mean_squared_error: 41.3505 - val_arousal_output_correlationMetric: nan - val_arousal_output_CCC: 0.0000e+00 - val_valence_output_root_mean_squared_error: 173.7525 - val_valence_output_correlationMetric: nan - val_valence_output_CCC: 0.0000e+00

# %% [markdown]
# Part 2
#
# Data is very large. So we will use a custom data generator to load batches of data from the files and then train on each batch simultaneously using the GPU of the computer

# %%
#!pip install keras --user
#!pip install tensorflow_addons --user
#!pip install tensorflow --user
#!pip install numba

#!pip install tensorflow-gpu --user
#!pip install numpy --user
#!pip install pydot --user
#!pip install opencv-python --user
#!pip install opencv-contrib-python --user
#!pip install cv2 --user
#!pip install krippendorff

#!pip install pandas
#!pip install matplotlib
#!pip install torch
#!pip install torchvision

#import torch
import numpy as np
import os
import glob

import skimage.io as io
import pandas as pd
#import cv2

from matplotlib import pyplot as plt
import random
#import time
import tensorflow as tf
import pathlib

#from matplotlib.patches import Circle

# %%
import os
import skimage.io as io
import torch
import torch.cuda
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
from IPython.core.display import HTML
from torch.utils.data import Dataset, DataLoader
import glob
import numpy
import random

import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Mar 30 21:34:45 2022

@author: moosa
"""

from pathlib import Path
import os
import random
from PIL import Image

from numpy import expand_dims


class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, img_folder, npy_folder, batch_size, shuffle=True):
        self.batch_size = batch_size
#         self.df = dataframe
#         self.num_classes = num_classes
        self.shuffle = shuffle
        self.img_folder = img_folder
        self.npy_folder = npy_folder
#         self.on_epoch_end()
        self.img_list = os.listdir(img_folder)
        self.indices = np.arange(0, len(self.img_list))
        if self.shuffle:
            random.shuffle(self.img_list)

    def __len__(self):
        return len(os.listdir(self.img_folder))

    def __getitem__(self, index):
        index = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        batch = [self.indices[k] for k in index]
        
        X, y = self.__get_data(batch)
        return X, y



    def __get_data(self, batch):
        
        X = []
        y = []
        
        for i, id in enumerate(batch):
            img_name = self.img_list[id]
            aro = np.load(os.path.join(self.npy_folder, Path(img_name).stem+'_aro.npy'))
            expa = np.load(os.path.join(self.npy_folder, Path(img_name).stem+'_exp.npy'))
            exp = to_categorical(expa,num_classes = 8)
            
            #exp = expand_dims(exps, axis=0)
            lnd = np.load(os.path.join(self.npy_folder, Path(img_name).stem+'_lnd.npy')).reshape(68,2)
            val = np.load(os.path.join(self.npy_folder, Path(img_name).stem+'_val.npy'))
            
            img = Image.open(os.path.join(self.img_folder,img_name)).convert('RGB')
            img = tf.keras.preprocessing.image.img_to_array(img)
            
            X = [img,lnd]
            y = [aro,val,exp]
            
        return X, y

# %%
def show(xx,yy,y1,y2,y3): 
    fig,ax = plt.subplots(1)
    #ax.set_aspect('equal')
    plt.imshow(xx.astype("uint8"))
    ax.text(5, 5, y3, bbox={'facecolor': 'white', 'pad': 10})
    
    #ax.text(5, 200, 'Arousal: 'y1, bbox={'facecolor': 'white', 'pad': 10})
    plt.scatter(yy[:, 0], yy[:, 1], s=10, marker='.')
    plt.pause(0.001)  # pause a bit so that plots are updated

# %%
import time
from tensorflow.keras.utils import to_categorical
#using data generators for training of models
data = DataGenerator('train_and_val_set-002/train_set/images', 'train_and_val_set-002/train_set/annotations', batch_size=64)

print(len(data))
i=0
for X,y in data:
    i=i+1
    print("Input shape:" ,X[0].shape,"\nLandmarks shape:" ,X[1].shape)
    print("\nArousal:" , y[0],"\nValence:" ,y[1],"\nExpression(one-hot) shape:", y[2].shape)
    show(X[0],X[1],y[0],y[1],y[2])
    #See random images with landmarks for 5 values then break generator
    if i==5:
        break
# Out:
# 287651
# Input shape: (224, 224, 3)
# Landmarks shape: (68, 2)
#
# Arousal: 0.015873
# Valence: 0.015873
# Expression(one-hot) shape: (8,)
# C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\matplotlib\text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# Input shape: (224, 224, 3)
# Landmarks shape: (68, 2)
#
# Arousal: 0.706349
# Valence: -0.444444
# Expression(one-hot) shape: (8,)
# Input shape: (224, 224, 3)
# Landmarks shape: (68, 2)
#
# Arousal: 0.0650743
# Valence: 0.677538
# Expression(one-hot) shape: (8,)
# Input shape: (224, 224, 3)
# Landmarks shape: (68, 2)
#
# Arousal: -0.0038279
# Valence: -0.0153116
# Expression(one-hot) shape: (8,)
# Input shape: (224, 224, 3)
# Landmarks shape: (68, 2)
#
# Arousal: 0.115887
# Valence: 0.526759
# Expression(one-hot) shape: (8,)

# %%
from tensorflow.keras import backend as K

def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def correlationMetric(x, y, axis=-2):
    """Metric returning the Pearson correlation coefficient of two tensors over some axis, default -2."""
    x = tf.convert_to_tensor(x)
    y = K.cast(y, x.dtype)
    n = tf.cast(tf.shape(x)[axis], x.dtype)
    xsum = tf.reduce_sum(x, axis=axis)
    ysum = tf.reduce_sum(y, axis=axis)
    xmean = xsum / n
    ymean = ysum / n
    xvar = tf.reduce_sum( tf.math.squared_difference(x, xmean), axis=axis)
    yvar = tf.reduce_sum( tf.math.squared_difference(y, ymean), axis=axis)
    cov = tf.reduce_sum( (x - xmean) * (y - ymean), axis=axis)
    corr = cov / tf.sqrt(xvar * yvar)
    return tf.constant(1.0, dtype=x.dtype) - corr

def CCC(y_true, y_pred):
    '''Lin's Concordance correlation coefficient: https://en.wikipedia.org/wiki/Concordance_correlation_coefficient
    
    The concordance correlation coefficient is the correlation between two variables that fall on the 45 degree line through the origin.
    
    It is a product of
    - precision (Pearson correlation coefficient) and
    - accuracy (closeness to 45 degree line)

    Interpretation:
    - `rho_c =  1` : perfect agreement
    - `rho_c =  0` : no agreement
    - `rho_c = -1` : perfect disagreement 
    
    Args: 
    - y_true: ground truth
    - y_pred: predicted values
    
    Returns:
    - concordance correlation coefficient (float)
    '''
    
    # covariance between y_true and y_pred
    N = K.int_shape(y_pred)[-1]
    s_xy = 1.0 / (N - 1.0 + K.epsilon()) * K.sum((y_true - K.mean(y_true)) * (y_pred - K.mean(y_pred)))
    # means
    x_m = K.mean(y_true)
    y_m = K.mean(y_pred)
    # variances
    s_x_sq = K.var(y_true)
    s_y_sq = K.var(y_pred)
    
    # condordance correlation coefficient
    ccc = (2.0*s_xy) / (s_x_sq + s_y_sq + (x_m-y_m)**2)
    
    return ccc

# %%
#I have tensorflow 2.0 installed so compatible addon is:
# !pip install tensorflow-addons==0.6.0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-addons==0.6.0 (from versions: 0.7.0, 0.7.1, 0.8.1, 0.8.2, 0.8.3, 0.9.0, 0.9.1, 0.10.0, 0.11.0, 0.11.1, 0.11.2, 0.12.0, 0.12.1, 0.13.0, 0.14.0, 0.15.0, 0.16.1)
# ERROR: No matching distribution found for tensorflow-addons==0.6.0

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import concatenate
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import AUC


############Needed to install old version of tensorflow to activate the GPU of the computer. Took a long time to figure that out
############After installing old version of tensorflow cannot find compatible version of tensorflow-addons for these metrics

#import tensorflow_addons as tfa
#from tensorflow_addons.metrics import MatthewsCorrelationCoefficient as CORR
#from tensorflow_addons.metrics import CohenKappa as Cohen_Kappa
#from tensorflow_addons.metrics import F1Score as F1_Score

# %% [markdown]
# Apply a Network and predict classification using image and landmark points according to the following model
# ![download-2.png](attachment:download-2.png)

# %%
# Creating a CNN model with many VGG blocks

# function for creating a vgg block
def vgg_block(layer_in, n_filters, n_conv):
	# add convolutional layers
	for _ in range(n_conv):
		layer_in = Conv2D(n_filters, (3,3), padding='same', activation='relu')(layer_in)
	# add max pooling layer
	layer_in = MaxPooling2D((2,2), strides=(2,2))(layer_in)
	return layer_in
 
# define model input
visible = Input(shape=(224, 224, 3))  #image
visible2 = Input(shape=(68, 2))   #expressions


# add vgg module
layer1 = vgg_block(visible, 64, 2)
# add vgg module
layer2 = vgg_block(layer1, 128, 2)
# add vgg module
layer3 = vgg_block(layer2, 256, 3)
# add vgg module
layer4 = vgg_block(layer3, 512, 3)
# add vgg module
layer5 = vgg_block(layer4, 512, 3)

layer6_1 = Flatten()(layer5)
layer6_2 = Flatten()(visible2)

layer6 = concatenate([layer6_1, layer6_2])
layer7 = Dense(4096, activation='relu')(layer6)
layer8 = Dense(4096, activation='relu')(layer7)


# Output layer for classification (1000 classes)
layer_class = Dense(8, activation='softmax')(layer8)


layer_arousal = Dense(1, activation='linear')(layer8)

layer_val = Dense(1, activation='linear')(layer8)


classification_output = Lambda(lambda x:x, name = "classification_output")(layer_class)
arousal_output = Lambda(lambda x:x, name = "arousal_output")(layer_arousal)
valence_output = Lambda(lambda x:x, name = "valence_output")(layer_val)

# create model
model = Model(inputs=[visible,visible2], outputs=[arousal_output, valence_output, classification_output])


#macro parameters
model.compile(loss=['categorical_crossentropy', 'mse', 'mse'],
              optimizer='adam', metrics={"classification_output":['accuracy',
                                                                  #Cohen_Kappa(num_classes=8),
                                                                  #F1_Score(num_classes=8),
                                                                  AUC(curve='ROC',name = 'AUC-ROC'), 
                                                                  AUC(curve='PR',name = 'AUC-PR')], 
                                         "arousal_output":['RootMeanSquaredError',
                                                          correlationMetric, 
                                                           CCC], 
                                         "valence_output":['RootMeanSquaredError',
                                                          correlationMetric,
                                                           CCC]}, 
              run_eagerly=True)



# summarize model
model.summary()
# plot model architecture
#plot_model(model, show_shapes=True, to_file='vgg_block.png')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 112, 112, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 256)  590080      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 512)  2359808     conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 512)  2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 512)  2359808     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 14, 14, 512)  2359808     conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 7, 7, 512)    0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 68, 2)]      0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 25088)        0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 136)          0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 25224)        0           flatten[0][0]
#                                                                  flatten_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4096)         103321600   concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4096)         16781312    dense[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            4097        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            4097        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            32776       dense_1[0][0]
# __________________________________________________________________________________________________
# arousal_output (Lambda)         (None, 1)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# valence_output (Lambda)         (None, 1)            0           dense_4[0][0]
# __________________________________________________________________________________________________
# classification_output (Lambda)  (None, 8)            0           dense_2[0][0]
# ==================================================================================================
# Total params: 134,858,570
# Trainable params: 134,858,570
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
print('Num GPUs Available: ', len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
#cannot for the life of me figure out why i have this error

model.fit_generator(generator=DataGenerator('train_and_val_set-002/train_set/images', 'train_and_val_set-002/train_set/annotations', batch_size=64),
                    use_multiprocessing=False,
                    workers=1)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\moosa\AppData\Local\Temp\ipykernel_13436\566274960.py", line 5, in <module>
#     workers=1)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 1297, in fit_generator
#     steps_name='steps_per_epoch')
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py", line 257, in model_iteration
#     batch_size = int(nest.flatten(batch_data)[0].shape[0])
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\moosa\AppData\Local\Temp\ipykernel_13436\566274960.py", line 5, in <module>
#     workers=1)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 1297, in fit_generator
#     steps_name='steps_per_epoch')
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py", line 257, in model_iteration
#     batch_size = int(nest.flatten(batch_data)[0].shape[0])
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\moosa\AppData\Local\Temp\ipykernel_13436\566274960.py", line 5, in <module>
#     workers=1)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 1297, in fit_generator
#     steps_name='steps_per_epoch')
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py", line 257, in model_iteration
#     batch_size = int(nest.flatten(batch_data)[0].shape[0])
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
#assuming the above model is trained
model.evaluate_generator(generator=DataGenerator('test_set/val_set/images', 'test_set/val_set/annotations', batch_size=1),
                    use_multiprocessing=False,
                    workers=1)

###getting same error here as well
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 243
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\moosa\AppData\Local\Temp\ipykernel_13436\1900478147.py", line 4, in <module>
#     workers=1)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 1364, in evaluate_generator
#     callbacks=callbacks)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py", line 265, in model_iteration
#     batch_outs = batch_function(*batch_data)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 1070, in test_on_batch
#     reset_metrics=reset_metrics)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py", line 319, in test_on_batch
#     x, y, sample_weight=sample_weight, extract_tensors_from_dataset=True)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 2534, in _standardize_user_data
#     training_utils.check_array_lengths(x, y, sample_weights)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py", line 663, in check_array_lengths
#     set_y = set_of_lengths(targets)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py", line 658, in set_of_lengths
#     for y in x
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py", line 659, in <listcomp>
#     if y is not None and not is_tensor_or_composite_tensor(y)
# IndexError: tuple index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\moosa\AppData\Local\Temp\ipykernel_13436\1900478147.py", line 4, in <module>
#     workers=1)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 1364, in evaluate_generator
#     callbacks=callbacks)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py", line 265, in model_iteration
#     batch_outs = batch_function(*batch_data)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 1070, in test_on_batch
#     reset_metrics=reset_metrics)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py", line 319, in test_on_batch
#     x, y, sample_weight=sample_weight, extract_tensors_from_dataset=True)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 2534, in _standardize_user_data
#     training_utils.check_array_lengths(x, y, sample_weights)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py", line 663, in check_array_lengths
#     set_y = set_of_lengths(targets)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py", line 658, in set_of_lengths
#     for y in x
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py", line 659, in <listcomp>
#     if y is not None and not is_tensor_or_composite_tensor(y)
# IndexError: tuple index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\moosa\AppData\Local\Temp\ipykernel_13436\1900478147.py", line 4, in <module>
#     workers=1)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 1364, in evaluate_generator
#     callbacks=callbacks)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_generator.py", line 265, in model_iteration
#     batch_outs = batch_function(*batch_data)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 1070, in test_on_batch
#     reset_metrics=reset_metrics)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py", line 319, in test_on_batch
#     x, y, sample_weight=sample_weight, extract_tensors_from_dataset=True)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training.py", line 2534, in _standardize_user_data
#     training_utils.check_array_lengths(x, y, sample_weights)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py", line 663, in check_array_lengths
#     set_y = set_of_lengths(targets)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py", line 658, in set_of_lengths
#     for y in x
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow_core\python\keras\engine\training_utils.py", line 659, in <listcomp>
#     if y is not None and not is_tensor_or_composite_tensor(y)
# IndexError: tuple index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3186, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2080, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "C:\Users\moosa\anaconda3\envs\tf-gpu7\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
